# %%
from src.functions.axes_distribution_functions import AxesWithNormalDistribution
from src.functions.center_points import PoissonAlgorithm
from src.utils.classes.cancer_nucleus import CancerNucleusTest

center= PoissonAlgorithm(128, 128,20, 30)
center.prepare_iterator()
axes = AxesWithNormalDistribution(15,11, 10,10)
c1 = CancerNucleusTest(center.generate_points(), axes)

center.generate_points()
# Out:
# Generated 31 centers
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 center.prepare_iterator()
#       7 axes = AxesWithNormalDistribution(15,11, 10,10)
# ----> 8 c1 = CancerNucleusTest(center.generate_points(), axes)
#      10 center.generate_points()
#
# File ~\PycharmProjects\Projekt_Inzynierski\src\utils\classes\cancer_nucleus.py:90, in CancerNucleusTest.__init__(self, center, axes, irregularity, angle, color, thickness, border_color, border_thickness)
#      87 def __init__(self, center, axes, irregularity=0.3, angle=0, color=(160, 83, 179),
#      88              thickness=-1, border_color=(107, 26, 121), border_thickness=2):
# ---> 90     super().__init__(
#      91         center=center,
#      92         axes= axes,
#      93         angle=angle,
#      94         color=color,
#      95         thickness=thickness,
#      96         border_color=border_color,
#      97         border_thickness=border_thickness
#      98     )
#      99     self.irregularity = irregularity
#
# TypeError: NucleiTest.__init__() got an unexpected keyword argument 'center'

# %%
import numpy as np
import cv2
image = np.zeros((300, 300, 3),   dtype=np.uint8)

c1.draw_nuclei(image)

cv2.imshow('Nucleus', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
