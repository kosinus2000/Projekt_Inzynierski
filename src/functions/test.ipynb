# %%
from src.functions.axes_distribution_functions import AxesWithNormalDistribution
from src.functions.center_points import PoissonAlgorithm
from src.utils.classes.cancer_nucleus import CancerNucleusTest

center= PoissonAlgorithm(128, 128,radius=30, k=20)
center.prepare_iterator()
center1. =
axes = AxesWithNormalDistribution(10,8,7,2)
c1 = CancerNucleusTest(center, axes)

center.generate_points()
# Out:
# Generated 17 centers
# [[69, 41],
#  [110, 39],
#  [59, 66],
#  [110, 66],
#  [85, 93],
#  [110, 111],
#  [15, 57],
#  [100, 10],
#  [56, 104],
#  [10, 118],
#  [47, 6],
#  [1, 29],
#  [20, 88]]

# %%
from src.data_generation.picture_generator import create_slide_image

create_slide_image(center, axes, CancerNucleusTest )
