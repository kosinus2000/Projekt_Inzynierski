# %%
from abc import ABC, abstractmethod

from functions.poisson_sampling import poisson_sampling


# class Losowanie:
#     def __init__(self, flag = False : bool):
#         self.flag = flag
#
#     if flag:
#

class Nucleus(ABC):
    def __init__(self,
                 center,
                 axes_size,
                 angle,
                 color,
                 thickness,
                 irregularity,
                 border_color,
                 border_thickness):


        self.center = center
        self.axes_size = axes_size
        self.angle = angle
        self.color = color
        self.thickness = thickness
        self.irregularity = irregularity
        self.border_color = border_color
        self.border_thickness = border_thickness

# %%
from utils.classes import cancer_nucleus


class cancer_nucleus(Nucleus):
    _lista_punktów = []
    _licznik = 0
    def __init__(self, center, axes_size, angle, color, thickness, irregularity, border_color, border_thickness):

        super().__init__(center, axes_size, angle, color, thickness, irregularity, border_color, border_thickness)
        if not cancer_nucleus._lista_punktów:
            _lista_punktów = poisson_sampling()

# %%
class Losowanie(ABC):
    @abstractmethod
    def losuj(self, zakres_od, zakres_do):
        pass

# %%
class RozkladNormalny(Losowanie):
    def losuj(self, zakres_od, zakres_do):
       # return(

        # )
        pass

# %%
def losowanie_centrum_bez_nakładania(rodzaj_losowania, wymiarxpowierzchni, wymiarypowierzchni, ilosc):
    x = wymiarxpowierzchni
    y = wymiarypowierzchni
