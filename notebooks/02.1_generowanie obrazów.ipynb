# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math
import noise

from src.functions.single_cell_generator import SingleCellGenerator, BorderLineThickness
from src.utils.cancer_nucleus import CancerNucleus

# %%
from src.functions.single_cell_generator import CalculateAxesSizeFromImageSize

proba = CalculateAxesSizeFromImageSize(500,500)

cell = SingleCellGenerator(500,500)
proba
# Out:
# (152, 103)

# %%
from src.functions.single_cell_generator import CalculateAxesSizeFromImageSize

proba = CalculateAxesSizeFromImageSize(64,64)
proba
# Out:
# (21, 10)

# %%
trye = BorderLineThickness(500,500)
trye
# Out:
# 8
